# %% [markdown]
# # Drzewa Klasyfikacyjne (Classification Trees)
#
# Drzewa klasyfikacyjne są strukturą danych stosowaną w uczeniu maszynowym, która modeluje decyzje lub klasyfikacje za pomocą sekwencji pytań lub testów.
#
# Formalnie, drzewo klasyfikacyjne $T$ jest funkcją $T: X \rightarrow Y$, gdzie $X$ jest przestrzenią wejściową (np. wektory cech) a $Y$ jest przestrzenią wyjściową (np. etykiety klas).
#
# ## Definicja
#
# Drzewo klasyfikacyjne można zdefiniować jako strukturę drzewiastą, gdzie:
#
# - Każdy węzeł wewnętrzny w drzewie reprezentuje test na jednym z atrybutów wejściowych, np. $x_i < \theta$.
# - Każda krawędź od węzła do jego dziecka reprezentuje wynik testu.
# - Każdy liść reprezentuje etykietę klasy (dla drzew klasyfikacyjnych) lub wartość rzeczywistą (dla drzew regresji).
#
# ## Algorytm Budowy Drzewa
#
# Poniżej jest opisany algorytm budowy drzewa klasyfikacyjnego, tzw. algorytm ID3:
#
# 1. Jeżeli wszystkie przykłady w bieżącym zbiorze danych mają tę samą etykietę klasy, stwórz liść z tą etykietą i zakończ.
# 2. W przeciwnym razie, dla każdego atrybutu $a$ oblicz miarę jakości podziału, np. zysk informacyjny.
# 3. Wybierz atrybut z największym zyskiem informacyjnym.
# 4. Stwórz nowy węzeł decyzyjny dla tego atrybutu.
# 5. Podziel bieżący zbiór danych na podzbiory, używając wartości atrybutu z nowego węzła.
# 6. Dla każdego podzbioru, powtórz proces (rekurencyjnie), tworząc nowe gałęzie drzewa.
#
# ## Miary Jakości Podziału
#
# Istnieje wiele miar jakości podziału. Dwie najpopularniejsze to zysk informacyjny i indeks Gini.
#
# ### Zysk Informacyjny
#
# Zysk informacyjny $IG$ dla danego atrybutu $a$ i zbioru danych $D$ definiowany jest jako:
#
# $$ IG(D, a) = H(D) - \sum_{v \in Values(a)} \frac{|D_v|}{|D|} H(D_v) $$
#
# gdzie:
# - $H(D)$ to entropia zbioru danych $D$,
# - $Values(a)$ to zbiór wszystkich możliwych wartości atrybutu $a$,
# - $D_v$ to podzbiór $D$ dla którego atrybut $a$ ma wartość $v$,
# - $|D|$ to liczba przykładów w zbiorze $D$,
# - $|D_v|$ to liczba przykładów w zbiorze $D_v$.
#
# ### Indeks Gini
#
# Indeks Gini $Gini(D)$ dla zbioru danych $D$ definiowany jest jako:
#
# $$ Gini(D) = 1 - \sum_{k=1}^{K} p_k^2 $$
#
# gdzie:
# - $K$ to liczba klas,
# - $p_k$ to proporcja przykładów klasy $k$ w zbiorze $D$.
#
# Indeks Gini dla podziału na podstawie atrybutu $a$ oblicza się jako ważoną średnią indeksów Gini dla podzbiorów:
#
# $$ Gini(D, a) = \sum_{v \in Values(a)} \frac{|D_v|}{|D|} Gini(D_v) $$
#
# ### Przykładowe drzewa klasyfikacyjne
#
# ![Classification Tree](https://www.solver.com/sites/default/files/ctree.gif "Classification Tree")
# ![Classification Tree](https://www.researchgate.net/profile/Loren-Roth/publication/227267151/figure/fig2/AS:671517780217856@1537113723021/Standard-classification-tree-A-and-iterative-classification-tree-A-and-B-models-C.png "Classification Tree")
# ![Classification Tree](https://www.researchgate.net/profile/Maggi-Kelly/publication/216637957/figure/fig2/AS:667653916065802@1536192506491/Classification-tree-model-of-disease-risk-Ovals-and-squares-represent-non-terminal-and.ppm "Classification Tree")

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("./loans.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.value_counts("Loan_Status")
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
df = df.dropna()

# %%
df.Loan_Status = df.Loan_Status.map({'Y': 1,'N': 0})
df.Gender=df.Gender.map({'Male': 1,'Female': 0})
df.Married=df.Married.map({'Yes': 1,'No': 0})
df.Dependents=df.Dependents.map({'0': 0,'1': 1,'2': 2,'3+': 3})
df.Education=df.Education.map({'Graduate': 1,'Not Graduate': 0})
df.Self_Employed=df.Self_Employed.map({'Yes': 1,'No': 0})
df.Property_Area=df.Property_Area.map({'Urban': 2,'Rural': 0,'Semiurban': 1})

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              1
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# 5    LP001011       1        1           2          1              1
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df = df.drop(columns="Loan_ID", axis=1)
y = df["Loan_Status"]
X = df.drop(columns="Loan_Status", axis=1)

# %%
df.value_counts("Loan_Status")
# Out:
# Loan_Status
# 1    332
# 0    148
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
"""
from sklearn.model_selection import GridSearchCV
clf = DecisionTreeClassifier()
#
# Create grid parameters for hyperparameter tuning
#
params =  {
    'min_samples_leaf': list(range(1, 50, 3)),
    'max_depth': list(range(5, 200, 10)),
    'min_samples_split':list(range(2, 25, 2))
}
#
# Create gridsearch instance
#
grid = GridSearchCV(estimator=clf,
                    param_grid=params,
                    cv=10,
                    n_jobs=1,
                    verbose=2,
                    scoring="f1")

grid.fit(X_train, y_train)

max_depth, min_samples_leaf, min_samples_split = grid.best_params_['max_depth'], grid.best_params_['min_samples_leaf'], grid.best_params_['min_samples_split']
"""
# Out:
# '\nfrom sklearn.model_selection import GridSearchCV\nclf = DecisionTreeClassifier()\n#\n# Create grid parameters for hyperparameter tuning\n#\nparams =  {\n    \'min_samples_leaf\': list(range(1, 50, 3)),\n    \'max_depth\': list(range(5, 200, 10)),\n    \'min_samples_split\':list(range(2, 25, 2))\n}\n#\n# Create gridsearch instance\n#\ngrid = GridSearchCV(estimator=clf,\n                    param_grid=params,\n                    cv=10,\n                    n_jobs=1,\n                    verbose=2,\n                    scoring="f1")\n\ngrid.fit(X_train, y_train)\n\nmax_depth, min_samples_leaf, min_samples_split = grid.best_params_[\'max_depth\'], grid.best_params_[\'min_samples_leaf\'], grid.best_params_[\'min_samples_split\']\n'

# %%
'''
print(f"""max_depth = {max_depth}
min_samples_leaf = {min_samples_leaf}
min_samples_split = {min_samples_split}
""")
'''
# Out:
# '\nprint(f"""max_depth = {max_depth}\nmin_samples_leaf = {min_samples_leaf}\nmin_samples_split = {min_samples_split}\n""")\n'

# %%
clf = DecisionTreeClassifier(max_depth=10, min_samples_leaf=15, min_samples_split=5)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=15, min_samples_split=5)

# %%
pred = clf.predict(X_test)

# %%
confusion_matrix = confusion_matrix(y_test, pred)
sns.heatmap(confusion_matrix, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.53      0.56        30
#            1       0.80      0.83      0.81        66
#
#     accuracy                           0.74        96
#    macro avg       0.69      0.68      0.69        96
# weighted avg       0.73      0.74      0.74        96

# %% [markdown]
# ## Analiza
#     W projekcie analitycznym z przedmiotu systemy uczące się rozwiązywaliśmy problem klasyfikowania do przydzielenia pożyczki.
#     Dane którymi został zasilony model pobrane zostały ze strony keggle.com. Na zbiór danych składają się rekordy zawierające informacje:
#         * Loan_ID – numer identyfikacyjny pożyczki
#         * Gender – płeć
#         * Married – stan cywilny
#         * Dependents – utrzymankowie
#         * Education – wykształcenie
#         * Self_Employed – samozatrudnienie
#         * ApplicantIncome – dochód wnioskodawcy
#         * CoapplicantIncome – dochód współwnioskodawcy
#         * LoanAmount – kwota kredytu(w tys)
#         * Loan_Amount_Term – termin kwoty pożyczki(w miesiącach)
#         * Credit_History – historia kredytowa
#         * Property_Area – obszar nieruchomości
#         * Loan_Status – stan kredytu
#
#
#         20% zbioru, zostało zastosowane jako dane testowe.
#
#         Problem z który rozwiązywalismy w ramach projektu, polega na zautomatyzowaniu procesu decyzji o przyznanie kredytu klientom indywidualnym w czasie rzeczywistym, na podstawie danych wypelnionych w formularzu online.
#     Postanowiono rozwiazać ten problem dzieląc klientów na kategorie, przy użyciu drzewa klasyfikacji. Model ten moze byc zastosowany w dziedzinie bankowosci, celem automatyzacji procesu.
#
#     Do oceny wydajności modelu zastosowano metryki takie jak:
#         * Precision - prezycja modelu,
#         * Recall-czułość modelu,
#         * F1-Score - średnia harmoniczna prezycji i odzysku,
#         * Accuracy - dokladność modelu,
#         * Macro average - średnia makro
#         * Weighted average - średnia ważona prezycji, czułości oraz F1
#
#         Dla klasy problemu 0 (nieprzyznane kredyty) precyzja wynosi 0.64 co onzacza, że w przypadku 64% pozytywnych predykcji było prawidłowych.
#     Oznacza to, że 36% odrzuconych wniosków zostałoby odrzuconych nieslusznie. Jest to ponad jedna trzecia - w przypadku tych decyzji prezycja modelu    jest daleka od przyzwoitej.
#
#         Dla klasy problemu 1 (przyznane kredyty) prezycja wynosi 0.88 co onzacza, ze w przypadku 88% pozytywnych predykcji było prawidłowych. Dla tej klasy precyzja jest znacznie wyższa,jednak w przypadku przyznania kredytu niesłusznie kredytodawca narażony jest na ryzyko niewypłacalności. Precyzja modelu na poziomie 0.88%, biorąc pod uwagę standardy branży bankowej i prezycje uzyskiwane dla problemów klasyfikacji dwuklasowej  jest raczej niska.
#
#         Czułość modelu dla klasy problemu 0 (nieprzyznane kredyty) wynosi 0.61, co oznacza że 61% rzeczywistych pozytywów zostało prawidłowo zaklasyfikowanych dla klasy 0.
#
#         Czułość modelu dla klasy problemu 1 (przyznane kredyty) wynosi 0.89, co oznacza że 89% rzeczywistych pozytywów zostało prawidłowo zaklasyfikowanych dla klasy 1.
#
#         Model jest bardziej czuły w przypadku decyzji o przydzielaniu kredytu, czułość na poziomie 61% dla klasy problemu 0, prawdopodobnie dysklasyfikuje model w komercyjnym użyciu.
#
#         Zwiększenie precyzji dla klasy 0: W przypadku gdy bank bardziej niż cokolwiek innego chce unikać udzielania pożyczek osobom niewypłacalnym, powinno dążyć się do zwiększenia precyzji dla klasy 0.
#         Przez poprawę zdolności modelu do identyfikacji prawdziwych negatywnych przypadków, bank może ograniczyć ryzyko niewłaściwego przyznawania pożyczek.Pożyczki dla osób wypłacalnych 0.89 są na przyzwoitym poziomie.
#
#
#             F1-Score dla klasy problemu 0 (nieprzyznane kredyty) wynosi 0.62, co oznacza, że w 62% przypadków model przewiduje każdą obserwację poprawnie.Jest to dostateczny wynik do poprawnego działania, gdyż w większej liczbie przypadków nasza predykcja będzie się zgadzała.Jednak w przypadku udzielania kredytów, wartość ta powinna być znacznie wyższa, aby trafność przyznawania kredytów była jak największa.
#             F1-Score dla klasy problemu 1 (przyznane kredyty) wynosi 0.88, co oznacza, że w 88% przypadków model przewiduje każdą obserwację poprawnie.Jest to bardzo wysoka i dobra wartość dla sektora bankowości, znaczna większość(w prawie 9 na 10 przypadków) ocena przyznania kredytu będzie prawidłowa, a bank będzie mógł odnieść zdecydowany zwrot z pożyczonych pieniędzy.
#
#         Support (ilosc probek w klasie) dla klasy 0 wyniosła 23, jest to bardzo niska ilosc, w porównaniu do 73 próbek dla klasy 1.
#     Mala ilosc probek może byc powodem dla którego osiągi modeli w tej klasie są znacząco niższe
#
#         Średnia makro - tj. bez uzgledniania wagi klas wyniosla odpowiednio  -.76, 0.75, 0.75 dla recyzji, czułosci i F1
#     Z kolei średnia uwzględniająca wagi poszczególnych klas ( liczniejsza klasa - większa waga) wyniosła 0.82 dla każdej metryki.
#
#         Ogólna dokładność (accuracy) wyniosła 0.82. Model sklasyfikował poprawnie 82% wszystkich przypadków w zbiorze danych. Jest to dość wysoka wartośc, jadnak nalezy zauwazyc ze w przypadku omawianego zbioru danych,
#     gdzie liczba przypadków w klasach znacząco się różni wartość ta może być myląca.
#
#         Aby poprawić powyższe metryki w przypadku modelu opartego o drzewo klasyfikacji można by poeksperymentować z parametrami takimi jak: maksymalna głębokość drzewa, minimalna liczba probek do podzialu, minimalna liczba probek w lisciu, maksymalna liczba cech. Mozna by rowniez zastosowac inne kryteium podziału
